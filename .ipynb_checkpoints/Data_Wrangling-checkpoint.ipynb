# %% [markdown]
# # IMPORTING DATA
#
# Begin with importing data using pandas read_csv function. For this, I parsed date on the "Day" column. I am unable to define the data types for each column as the data needs to be cleaned before the correct data type can be specified.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

data = pd.read_csv("C:/Users/alexp/DATASCIENCE/GitHub/Captsone_Two_Data/Raw_Data/Raw_Data.csv",parse_dates=['Day'])

# %% [markdown]
# ## Initial Data Review
#
# Below I reviewed the shape of my data and checked the column names to ensure the ALL the data imported correctly.

# %%
data.shape
# Out:
# (107730, 53)

# %%
data.columns
# Out:
# Index(['Day', 'Campaign status', 'Campaign', 'Budget name', 'Currency code',
#        'Budget', 'Budget type', 'Status', 'Status reasons',
#        'Optimization score', 'Bid strategy type', 'Campaign type', 'Impr.',
#        'Clicks', 'CTR', 'Avg. CPC', 'Cost', 'Conversions',
#        'Conversions (by conv. time)', 'Conv. value (by conv. time)',
#        'All conv.', 'All conv. value', 'Store visits', 'Cost / conv.',
#        'Conv. rate', 'Conv. value', 'Conv. value / cost', 'Search impr. share',
#        'Search lost IS (rank)', 'Search lost IS (budget)', 'Search top IS',
#        'Search lost top IS (rank)', 'Search lost top IS (budget)',
#        'Search abs. top IS', 'Search lost abs. top IS (rank)',
#        'Search lost abs. top IS (budget)', 'Search exact match IS',
#        'Click share', 'Invalid clicks', 'Impr. (Abs. Top) %', 'Impr. (Top) %',
#        'Value / conv.', 'View-through conv.', 'View-through store visits',
#        'Store visit value', '% new sessions', 'Store Sales', 'Store Visits',
#        'Store Revenue', 'Avg. target CPA optimization', 'Avg. target CPA',
#        'Avg. target ROAS optimization', 'Avg. target ROAS'],
#       dtype='object')

# %% [markdown]
# # Updating Data Types
#
# most columns listed above were imported with the wrong data type due to commas (",") in row values. The next step is removing any unwanted symbols and updating the data types. To do this, i used the "str.replace" method and "astype" method.

# %%
for col in ['Clicks', 'Impr.']:
    data[col]=data[col].str.replace(",","").astype(int)
    
for col in ['Conv. value', 'All conv.','All conv. value']:
    data[col]=data[col].str.replace(",","").astype(float)    

data["Store Revenue"] = data["Store Revenue"].str.replace("£","").str.replace(",","").astype(float)

# %%
for col in ["Click share","Search impr. share","Search lost IS (rank)","Search lost IS (budget)"]:
    data[col] = data[col].str.replace(" --","0").str.replace("< 10%","0.09").str.replace(">","").str.replace("%","").str.strip().astype(float)

# %%
data['CR'] = data['Conversions']/data['Clicks']
data['CPA'] = data['Cost']/data['Conversions']
data['CTR'] = data['Clicks']/data['Impr.']
data['CPC'] = data['Cost']/data['Clicks']
data['AOV'] = data['Conv. value']/data['Cost']

# %%
data.fillna(0,inplace=True)
data.replace([np.inf, -np.inf], 0,inplace=True)
data.head()
# Out:
#          Day Campaign status  \
# 0 2019-02-15         Enabled
# 1 2019-05-11         Enabled
# 2 2019-01-10         Enabled
# 3 2020-02-12         Enabled
# 4 2021-03-19         Enabled
#
#                                             Campaign Budget name  \
# 0       {Google - Generic - Beds Brands - NVK - BMM}          --
# 1       {Google - Generic - Beds Brands - NVK - BMM}          --
# 2  {Google - Generic - Mattresses Competitors - N...          --
# 3       {Google - Generic - Beds Brands - NVK - BMM}          --
# 4       {Google - Generic - Beds Brands - NVK - BMM}          --
#
#   Currency code  Budget Budget type    Status              Status reasons  \
# 0           GBP   630.0       Daily  Eligible  some ads limited by policy
# 1           GBP   630.0       Daily  Eligible  some ads limited by policy
# 2           GBP   630.0       Daily  Eligible                     unknown
# 3           GBP   630.0       Daily  Eligible  some ads limited by policy
# 4           GBP   630.0       Daily  Eligible  some ads limited by policy
#
#    Optimization score  ... Store Visits Store Revenue  \
# 0               78.63  ...          0.0           0.0
# 1               78.63  ...          0.0           0.0
# 2               63.58  ...          1.0           0.0
# 3               78.63  ...          0.0           0.0
# 4               78.63  ...          0.0           0.0
#
#    Avg. target CPA optimization  Avg. target CPA  \
# 0                            --               --
# 1                            --               --
# 2                            --               --
# 3                            --               --
# 4                            --               --
#
#    Avg. target ROAS optimization Avg. target ROAS   CR  CPA       CPC  AOV
# 0                             --               --  0.0  0.0  0.000000  0.0
# 1                             --               --  0.0  0.0  0.000000  0.0
# 2                             --               --  0.0  0.0  0.483846  0.0
# 3                             --               --  0.0  0.0  0.000000  0.0
# 4                             --               --  0.0  0.0  0.000000  0.0
#
# [5 rows x 57 columns]

# %% [markdown]
# # Core Dataset
#
# Now that the data types are updated, we can create our core dataset.

# %%
core_df = data[['Day','Campaign','Clicks', 'Impr.','Cost','Conversions','Conv. value','Store Visits','Store Revenue','CR','CPA','CTR','CPC','AOV']]

# %%
core_df
# Out:
#               Day                                           Campaign  Clicks  \
# 0      2019-02-15       {Google - Generic - Beds Brands - NVK - BMM}       0
# 1      2019-05-11       {Google - Generic - Beds Brands - NVK - BMM}       0
# 2      2019-01-10  {Google - Generic - Mattresses Competitors - N...      13
# 3      2020-02-12       {Google - Generic - Beds Brands - NVK - BMM}       0
# 4      2021-03-19       {Google - Generic - Beds Brands - NVK - BMM}       0
# ...           ...                                                ...     ...
# 107725 2019-07-10    {Google - Generic - Mattress Sizes - NVK - BMM}      95
# 107726 2020-10-17      {Google - Generic - Beds Sizes - HVK - Exact}     332
# 107727 2020-06-07   {Google - Generic - Sleep Matters - NVK - Exact}       0
# 107728 2020-10-15  {Google - Generic - Mattresses Competitors - N...      64
# 107729 2019-11-03  {Google - Generic - Sofa + Guest Beds - NVK - ...     148
#
#         Impr.    Cost  Conversions  Conv. value  Store Visits  Store Revenue  \
# 0           0    0.00         0.00         0.00           0.0           0.00
# 1           0    0.00         0.00         0.00           0.0           0.00
# 2        1943    6.29         0.00         0.00           1.0           0.00
# 3           0    0.00         0.00         0.00           0.0           0.00
# 4           2    0.00         0.00         0.00           0.0           0.00
# ...       ...     ...          ...          ...           ...            ...
# 107725  30172   96.17         2.08       367.18           0.0         692.44
# 107726   5155  141.02         1.06         9.67          10.0         940.73
# 107727      0    0.00         0.00         0.00           0.0           0.00
# 107728   1210   22.43         0.00         0.00           4.0           0.00
# 107729   5066   43.75         2.00       598.00           5.0        1060.60
#
#               CR         CPA       CTR       CPC        AOV
# 0       0.000000    0.000000  0.000000  0.000000   0.000000
# 1       0.000000    0.000000  0.000000  0.000000   0.000000
# 2       0.000000    0.000000  0.006691  0.483846   0.000000
# 3       0.000000    0.000000  0.000000  0.000000   0.000000
# 4       0.000000    0.000000  0.000000  0.000000   0.000000
# ...          ...         ...       ...       ...        ...
# 107725  0.021895   46.235577  0.003149  1.012316   3.818031
# 107726  0.003193  133.037736  0.064403  0.424759   0.068572
# 107727  0.000000    0.000000  0.000000  0.000000   0.000000
# 107728  0.000000    0.000000  0.052893  0.350469   0.000000
# 107729  0.013514   21.875000  0.029214  0.295608  13.668571
#
# [107730 rows x 14 columns]

# %%
core_df.dtypes
# Out:
# Day              datetime64[ns]
# Campaign                 object
# Clicks                    int32
# Impr.                     int32
# Cost                    float64
# Conversions             float64
# Conv. value             float64
# Store Visits            float64
# Store Revenue           float64
# CR                      float64
# CPA                     float64
# CTR                     float64
# CPC                     float64
# AOV                     float64
# dtype: object

# %%
core_df.describe()
# Out:
#               Clicks         Impr.           Cost    Conversions  \
# count  107730.000000  1.077300e+05  107730.000000  107730.000000
# mean      167.763121  7.550237e+03      70.762098       2.226363
# std       624.870090  4.509005e+04     298.634425      11.042734
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%         0.000000  0.000000e+00       0.000000       0.000000
# 50%         4.000000  3.200000e+01       0.610000       0.000000
# 75%        95.000000  2.005000e+03      29.790000       0.910000
# max     31074.000000  2.856543e+06   21549.840000     697.460000
#
#          Conv. value   Store Visits  Store Revenue             CR  \
# count  107730.000000  107730.000000  107730.000000  107730.000000
# mean     1008.693889       7.529670     832.922419       0.007231
# std      5370.788128      31.453462    3914.106541       0.030995
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%       156.975000       2.710000       0.000000       0.004271
# max    353621.870000     874.000000  133685.660000       1.550000
#
#                  CPA            CTR            CPC            AOV
# count  107730.000000  107730.000000  107730.000000  107730.000000
# mean       51.835437       0.102824       0.211784      26.244725
# std       647.707334       0.208323       0.275601     404.749809
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.009814       0.090661       0.000000
# 75%         5.913100       0.068966       0.353779       2.478535
# max     55133.000000       3.000000       3.340000   45995.000000

# %% [markdown]
# ## Removing zero values
#
# After reviewing my new data set, i noticed there were numerous rows with 0 values. This can skew statistics like the mean, std etc... Lets remove all zero values and filter data just on generic campaigns.

# %%
nonZeroImpr = (core_df['Campaign'].str.contains('Generic',regex=False)) & (core_df["Impr."] >= 100) & (core_df["Clicks"] >= 100)

# %%
non_zero_df = core_df[nonZeroImpr]
non_zero_df.head()
# Out:
#           Day                                           Campaign  Clicks  \
# 7  2019-02-10        {Google - Generic - Beds Sizes - NVK - BMM}     305
# 10 2019-11-19        {Google - Generic - Headboards - NVK - BMM}     114
# 22 2019-03-30        {Google - Generic - Beds Sizes - NVK - BMM}     148
# 25 2019-08-12  {Google - Generic - Sofa + Guest Beds - NVK - ...     116
# 32 2019-10-01        {Google - Generic - Beds Sizes - NVK - BMM}     304
#
#     Impr.    Cost  Conversions  Conv. value  Store Visits  Store Revenue  \
# 7   52340  112.88         1.32      1015.09           7.0        1708.31
# 10  18119   58.83         0.00         0.00           3.0           0.00
# 22  23942   63.63         0.33        60.00           4.0           0.00
# 25  13668   56.13         0.00         0.00           7.0         845.95
# 32  67260  213.86         1.58       421.96          12.0        2018.81
#
#           CR         CPA       CTR       CPC       AOV
# 7   0.004328   85.515152  0.005827  0.370098  8.992647
# 10  0.000000    0.000000  0.006292  0.516053  0.000000
# 22  0.002230  192.818182  0.006182  0.429932  0.942951
# 25  0.000000    0.000000  0.008487  0.483879  0.000000
# 32  0.005197  135.354430  0.004520  0.703487  1.973066

# %%
non_zero_df.shape
# Out:
# (18108, 14)

# %%
non_zero_df['Campaign'].unique()
# Out:
# array(['{Google - Generic - Beds Sizes - NVK - BMM}',
#        '{Google - Generic - Headboards - NVK - BMM}',
#        '{Google - Generic - Sofa + Guest Beds - NVK - BMM}',
#        '{Google - Generic - Beds - HVK - Exact}',
#        '{Google - Generic - Beds Brands - NVK - BMM}',
#        '{Google - Shopping - Generic - Kids}',
#        '{Google - Generic - Mattress Sizes - HVK - BMM}',
#        '{Google - Shopping - Generic - Furniture}',
#        '{Google - Generic - Mattresses Competitors - NVK - BMM}',
#        '{Google - Shopping - Generic - Mattresses}',
#        '{Google - Shopping - Generic - Bedding}',
#        '{Google - Shopping - Generic - Bedding - Local}',
#        '{Google - Shopping - Generic - Furniture - Local}',
#        '{Google - Shopping - Generic - Headboards}',
#        '{Google - Shopping - Generic - Beds}',
#        '{Google - Shopping - Generic - Sofa Beds & Guest Beds}',
#        '{Google - Shopping - Generic - Kids - Local}',
#        '{Google - Shopping - Generic - Beds - Local}',
#        '{Google - Shopping - Generic - Sofa Beds & Guest Beds - Local}',
#        '{Google - Generic - Beds - NVK - Exact}',
#        '{Google - Shopping - Generic - Headboards - Local}',
#        '{Google - Shopping - Generic - Mattresses - Local}',
#        '{Google - Generic - Mattresses Brands - NVK - BMM}',
#        '{Google - Generic - Mattress Sizes - HVK - Exact}',
#        '{Google - Generic - Mattress Sizes - NVK - Exact}',
#        '{Google - Generic - Beds Brands - NVK - Exact}',
#        '{Google - Generic - Awareness - NVK - Exact}',
#        '{Google - Generic - Mattresses - HVK - BMM}',
#        '{Google - Generic - Beds Sizes - HVK - Exact}',
#        '{Google - Generic - Child Beds - NVK - Exact}',
#        '{Google - Generic - Headboards - NVK - Exact}',
#        '{Google - Generic - Beds Competitors - NVK - Exact}',
#        '{Google - Generic - Beds Competitors - NVK - BMM}',
#        '{Google - Generic - Beds - HVK - BMM}',
#        '{Google - Generic - Sofa + Guest Beds - NVK - Exact}',
#        '{Google - Generic - Mattresses Competitors - NVK - Exact}',
#        '{Google - Generic - Beds Sizes - NVK - Exact}',
#        '{Google - Generic - Mattresses - NVK - BMM}',
#        '{Google - Generic - Mattresses - NVK - Exact}',
#        '{Google - Generic - Beds - NVK - BMM}',
#        '{Google - Generic - Mattress Sizes - NVK - BMM}',
#        '{Google - Generic - Awareness - NVK - BMM}',
#        '{Google - Generic - Mattresses - HVK - Exact}',
#        '{Google - Generic - Mattresses Brands - NVK - Exact}',
#        '{Google - Generic - Sleep Matters - NVK - Exact}',
#        '{Google - Generic - Beds Sizes - HVK - BMM}',
#        '{Google - Generic - Child Beds - NVK - BMM}',
#        '{Google - Generic - Sleep Matters - NVK - BMM}'], dtype=object)

# %% [markdown]
# # Sale Distribution

# %%
Avg_Sales = non_zero_df.groupby("Campaign")[["Conversions","Conv. value"]].mean().reset_index().sort_values("Conversions", ascending=False)
campaigns = Avg_Sales["Campaign"]
conv = Avg_Sales["Conversions"]
sales = Avg_Sales["Conv. value"]
# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.bar(campaigns[0:10], conv[0:10])
width = 0.4
plt.title("Top 10 Campaigns - Avg Sales")      
plt.ylabel("Avg Sales")
plt.xticks(rotation=90) 
plt.xticks(rotation=90) 
# Show Plot
plt.show()

# %%
non_zero_df.hist(figsize=(15,10),bins=1000)
plt.subplots_adjust(hspace=0.5);

# %%
sns.scatterplot(x='AOV',y='Clicks',data=non_zero_df)
# Out:
# <AxesSubplot:xlabel='AOV', ylabel='Clicks'>

# %% [markdown]
# # Correlation Analysis

# %%
sns.pairplot(non_zero_df)

# %%
plt.figure(figsize=(40,20))
sns.heatmap(non_zero_df.corr())
# Out:
# <AxesSubplot:>

# %%
non_zero_df.corr()
# Out:
#                  Clicks     Impr.      Cost  Conversions  Conv. value  \
# Clicks         1.000000  0.937960  0.928945     0.878315     0.884434
# Impr.          0.937960  1.000000  0.851574     0.838604     0.838991
# Cost           0.928945  0.851574  1.000000     0.840706     0.839919
# Conversions    0.878315  0.838604  0.840706     1.000000     0.967281
# Conv. value    0.884434  0.838991  0.839919     0.967281     1.000000
# Store Visits   0.705541  0.659941  0.637182     0.482526     0.470088
# Store Revenue  0.688107  0.619664  0.644891     0.523962     0.527921
# CR             0.028564  0.020891  0.042243     0.252004     0.161546
# CPA           -0.017246 -0.015407 -0.007827    -0.043953    -0.038457
# CTR           -0.059976 -0.256230  0.033248    -0.051256    -0.030899
# CPC           -0.013312 -0.062263  0.193226     0.011421     0.013318
# AOV            0.054727  0.054113  0.003670     0.149083     0.171664
#
#                Store Visits  Store Revenue        CR       CPA       CTR  \
# Clicks             0.705541       0.688107  0.028564 -0.017246 -0.059976
# Impr.              0.659941       0.619664  0.020891 -0.015407 -0.256230
# Cost               0.637182       0.644891  0.042243 -0.007827  0.033248
# Conversions        0.482526       0.523962  0.252004 -0.043953 -0.051256
# Conv. value        0.470088       0.527921  0.161546 -0.038457 -0.030899
# Store Visits       1.000000       0.831250 -0.003268 -0.009913 -0.047217
# Store Revenue      0.831250       1.000000  0.012930 -0.010928  0.017203
# CR                -0.003268       0.012930  1.000000 -0.107934  0.091377
# CPA               -0.009913      -0.010928 -0.107934  1.000000 -0.009904
# CTR               -0.047217       0.017203  0.091377 -0.009904  1.000000
# CPC                0.033871       0.078781  0.103809  0.039203  0.361977
# AOV                0.015919       0.028860  0.483562 -0.073614 -0.024712
#
#                     CPC       AOV
# Clicks        -0.013312  0.054727
# Impr.         -0.062263  0.054113
# Cost           0.193226  0.003670
# Conversions    0.011421  0.149083
# Conv. value    0.013318  0.171664
# Store Visits   0.033871  0.015919
# Store Revenue  0.078781  0.028860
# CR             0.103809  0.483562
# CPA            0.039203 -0.073614
# CTR            0.361977 -0.024712
# CPC            1.000000 -0.186888
# AOV           -0.186888  1.000000

# %% [markdown]
# Correlation analysis shows the best correlations is between Clicks, Impressions, Cost, Conversions and Conv. Value. We will use these columns to predict our models in the next section.

# %% [markdown]
# # Summary
#
# To conclude, we have:<br>
# 1.) Removed unwanted values from rows<br>
# 2.) Updated data types<br>
# 3.) Created new dataframe with the core columns needed for my project<br>
# 4.) Removed zero value rows<br>
# 5.) Exploratory Data Analysis (EDA) and identified which columns should be included in the models
